# %% [markdown]
# <a href="https://colab.research.google.com/github/deevena30/WIDS_STUDY_OF_MODELS/blob/main/SOM1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
